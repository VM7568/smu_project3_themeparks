# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('Saferparks-dataset-2017-v4.csv', encoding='cp1252')
data.head()
# Out:
#     acc_id   acc_date acc_state   acc_city fix_port  \
# 0  1005813  6/12/2010        OH  Cleveland        F
# 1  1004032  6/12/2010        OH  Cleveland        P
# 2  1007658  7/10/2010        CA    Anaheim        F
# 3  1007098  7/10/2010        CA   Carlsbad        F
# 4  1000094  7/29/2010        CO  Littleton        F
#
#                                               source  \
# 0                          Ohio Dept. of Agriculture
# 1   United States Consumer Product Safety Commission
# 2  California Division of Occupational Safety and...
# 3  California Division of Occupational Safety and...
# 4         Colorado Division of Oil and Public Safety
#
#                         bus_type industry_sector     device_category  \
# 0  Sports or recreation facility      recreation          inflatable
# 1  Sports or recreation facility      recreation          inflatable
# 2                 Amusement park  amusement ride          water ride
# ...

# %%
df = pd.DataFrame(data)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5516 entries, 0 to 8350
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acc_id                5516 non-null   int64
#  1   acc_date              5516 non-null   object
#  2   acc_state             5516 non-null   object
#  3   acc_city              5398 non-null   object
#  4   fix_port              5516 non-null   object
#  5   source                5516 non-null   object
#  6   bus_type              5516 non-null   object
#  7   industry_sector       5516 non-null   object
#  8   device_category       5516 non-null   object
#  9   device_type           5516 non-null   object
#  10  tradename_or_generic  5516 non-null   object
#  11  manufacturer          3462 non-null   object
#  12  num_injured           5514 non-null   float64
#  13  age_youngest          5100 non-null   float64
#  14  gender                5083 non-null   object
# ...

# %%
df = df['acc_city'].dropna()
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'acc_city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df = df['acc_city'].dropna()
#       2 df.head()
#
# ...
