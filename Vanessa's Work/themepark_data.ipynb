# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import json
import requests
import time
import seaborn as sns
from api_keys1 import API_KEY
from api_keys1 import gkey

# %%
# import gmaps
# gmaps.configure(gkey)

# %%
#import sample csv
file="sample_df.csv"
pd.set_option('display.max_columns', None)
df = pd.read_csv(file, encoding='cp1252')
df.head()
# Out:
#    Unnamed: 0  acc_id    acc_date acc_state     acc_city fix_port  \
# 0        1986  918339  2006-06-12        CA  Chula Vista        F
# 1        5913  920274  2003-06-13        CA       Clovis        F
# 2         345  916530  2007-09-08        TX            0        F
# 3        7638  910279  2002-06-19        IL            0        P
# 4        5790  911785  2003-06-28        NC    Charlotte        U
#
#                                               source            bus_type  \
# 0  California Division of Occupational Safety and...          Water park
# 1  California Division of Occupational Safety and...          Water park
# 2                           Texas Dept. of Insurance      Amusement park
# 3                       Illinois Department of Labor  Carnival or rental
# 4                      North Carolina Dept. of Labor             Unknown
#
#   industry_sector device_category             device_type  \
# 0      water park     water slide       Family raft slide
# ...

# %%
# Drop unneeded index column
df.drop("Unnamed: 0", axis=1, inplace=True) 
df.head()
# Out:
#    acc_id    acc_date acc_state     acc_city fix_port  \
# 0  918339  2006-06-12        CA  Chula Vista        F
# 1  920274  2003-06-13        CA       Clovis        F
# 2  916530  2007-09-08        TX            0        F
# 3  910279  2002-06-19        IL            0        P
# 4  911785  2003-06-28        NC    Charlotte        U
#
#                                               source            bus_type  \
# 0  California Division of Occupational Safety and...          Water park
# 1  California Division of Occupational Safety and...          Water park
# 2                           Texas Dept. of Insurance      Amusement park
# 3                       Illinois Department of Labor  Carnival or rental
# 4                      North Carolina Dept. of Labor             Unknown
#
#   industry_sector device_category             device_type  \
# 0      water park     water slide       Family raft slide
# 1      water park     water slide             Speed slide
# ...

# %%
#rename column
df.rename(columns = {'Address':'address'}, inplace = True)
df.head()
# Out:
#    acc_id    acc_date acc_state     acc_city fix_port  \
# 0  918339  2006-06-12        CA  Chula Vista        F
# 1  920274  2003-06-13        CA       Clovis        F
# 2  916530  2007-09-08        TX            0        F
# 3  910279  2002-06-19        IL            0        P
# 4  911785  2003-06-28        NC    Charlotte        U
#
#                                               source            bus_type  \
# 0  California Division of Occupational Safety and...          Water park
# 1  California Division of Occupational Safety and...          Water park
# 2                           Texas Dept. of Insurance      Amusement park
# 3                       Illinois Department of Labor  Carnival or rental
# 4                      North Carolina Dept. of Labor             Unknown
#
#   industry_sector device_category             device_type  \
# 0      water park     water slide       Family raft slide
# 1      water park     water slide             Speed slide
# ...

# %%
#Change data types
df["acc_date"] = pd.to_datetime(df["acc_date"])
df["year"] = df["year"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acc_id                1000 non-null   int64
#  1   acc_date              1000 non-null   datetime64[ns]
#  2   acc_state             1000 non-null   object
#  3   acc_city              1000 non-null   object
#  4   fix_port              1000 non-null   object
#  5   source                1000 non-null   object
#  6   bus_type              1000 non-null   object
#  7   industry_sector       1000 non-null   object
#  8   device_category       1000 non-null   object
#  9   device_type           1000 non-null   object
#  10  tradename_or_generic  1000 non-null   object
#  11  manufacturer          1000 non-null   object
#  12  num_injured           1000 non-null   int64
#  13  age_youngest          1000 non-null   float64
# ...

# %%
# df["acc_city"] = df.acc_city.replace("None", "na")
# df

# %%
address = df.address[0]
address

# %%
#Get location data from opwnweathermap.org

url = f"http://api.openweathermap.org/geo/1.0/direct?q={address}&appid={API_KEY}"
response = requests.get(url)

data = response.json()

if (len(data) > 0):
    location = data[0]
    print(location)

# %%
# #Loop to get location info for all addresses

# rows = []

# for address in df1.address:
#     print(address)
    
#     # create URL
#     url = f"http://api.openweathermap.org/geo/1.0/direct?q={address}&appid={API_KEY}"
#     response = requests.get(url)
    
#     # get data
#     data = response.json()

#     if (len(data) > 0):
#         location = data[0]
        
#         # parse data
#         lat = location["lat"]
#         lon = location["lon"]
#         city = location["name"]
#         state = location.get("state")
        
#         # make row
#         row = {"latitude": lat,
#               "longitude": lon,
#               "clean_city": city,
#               "clean_state": state}
        
#     else:
#         row = {"latitude": np.nan,
#               "longitude": np.nan,
#               "clean_city": None,
#               "clean_state": None}
    
#     rows.append(row)
#     time.sleep(1)

# %%
# #Google map

# # get data
# data = df_win.loc[:, ["latitude", "longitude"]].dropna()

# # Create BASE, init the graph
# figure_layout = {
#     'width': '800px',
#     'height': '600px',
#     'border': '0px',
#     'padding': '1px',
#     'margin': '0 auto 0 auto'
# }
# fig = gmaps.figure(layout=figure_layout, map_type='HYBRID')

# # init the overlay layers
# heat = gmaps.heatmap_layer(data)
# fig.add_layer(heat)


# # show the plot
# fig

# %%
# #BAR CHART HORIZONTAL 
# # step 1 - get the data
# states = df.clean_state.value_counts(ascending=True)

# x = states.index
# y = states.values

# # step 2 - make/init the plot
# fig = plt.figure(figsize=(10, 8))
# plt.barh(x, y, color="pink")

# # step 3 - customization
# plt.xlabel("# of Contestants per State", fontname = "Helvetica", fontsize=16)
# plt.ylabel("States", fontname = "Helvetica", fontsize=10)
# plt.title("Home States of Contestants", fontsize=24, fontweight="bold", fontname = "Helvetica")
# plt.xticks(fontsize=10, rotation=0)
# plt.yticks(fontsize=10)
# plt.grid(axis="x", alpha=0.25)

# # step 4 - show/save the plot
# plt.show()

# %%
# #Bar chart 
# states = df.loc[df["Season Bin"] == "15-21"].clean_state.value_counts().head(5)
# x = states.index
# y = states.values

# # step 2 - make/init the plot
# fig = plt.figure(figsize=(10, 8))
# plt.bar(x, y,  color="pink")

# # step 3 - customization
# plt.ylabel("# of Contestants", fontname = "Helvetica", fontsize=16)
# plt.title("Seasons 15-21: Top 5 States Contestants Are From", fontsize=22, fontweight="bold", fontname = "Helvetica")
# plt.xticks(fontsize=14, rotation=0)

# plt.grid(axis="y", alpha=0.25)

# # step 4 - show/save the plot
# plt.show()

# %%
df
